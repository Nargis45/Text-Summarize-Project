# %%
# !conda create --name textS python=3.8 -y
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\nasreenn\AppData\Local\anaconda3\envs\textS
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       haa95532_0         123 KB
#     openssl-3.0.12             |       h2bbff1b_0         7.4 MB
#     pip-23.3                   |   py38haa95532_0         2.8 MB
#     python-3.8.18              |       h1aa4202_0        20.5 MB
#     setuptools-68.0.0          |   py38haa95532_0         925 KB
#     wheel-0.41.2               |   py38haa95532_0         126 KB
#     ------------------------------------------------------------
#                                            Total:        31.8 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
#!pip install -r requirements.txt
